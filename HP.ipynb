# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')

# %%
data = pd.read_csv('E:/dataset.csv')

# %%
data.plot(kind='scatter',x='age', y='height')

# %%
import seaborn as sns
sns.lmplot(x='age',y='height',data=data,fit_reg=True)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_predict

# %%
lr = LinearRegression()
ob1 = data.loc[:, data.columns != 'height']
ob2 = data.height
# cross_val_predict returns an array of the same size as `y` where each entry
# is a prediction obtained by cross validation:
predicted = cross_val_predict(lr, ob1, ob2, cv=10)

fig, ax = plt.subplots()
ax.scatter(target, predicted, edgecolors=(0, 0, 0))
ax.plot([target.min(), target.max()], [target.min(), target.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
error = mean_squared_error(target, predicted)
print("Mean Squared Error : {}".format(error))
# Out:
# Mean Squared Error : 5.550646830984755

# %%
data['squared_age'] = data['age'] ** 2

# %%
data['squared_weight'] = data['weightLb'] ** 2

# %%
data.head()
# Out:
#    sex       age  ageMonth  height  weightLb  squared_age  squared_weight
# 0    0  11.91667       143    56.3      85.0   142.007024         7225.00
# 1    0  12.91667       155    62.3     105.0   166.840364        11025.00
# 2    0  12.75000       153    63.3     108.0   162.562500        11664.00
# 3    0  13.41667       161    59.0      92.0   180.007034         8464.00
# 4    0  15.91667       191    62.5     112.5   253.340384        12656.25

# %%
lr = LinearRegression()
ob1 = data.loc[:, data.columns != 'height']
ob2 = data.height
# cross_val_predict returns an array of the same size as `y` where each entry
# is a prediction obtained by cross validation:
predicted = cross_val_predict(lr, ob1, ob2, cv=10)

fig, ax = plt.subplots()
ax.scatter(target, predicted, edgecolors=(0, 0, 0))
ax.plot([target.min(), target.max()], [target.min(), target.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
error = mean_squared_error(target, predicted)
print("Mean Squared Error : {}".format(error))
# Out:
# Mean Squared Error : 4.86678610362832
